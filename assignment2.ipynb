# %% [markdown]
# # QUESTION NO1

# %%
data={'measure_x':[24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00],
'name_of_company':['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']}

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
Q1= pd.DataFrame(data)
Q1
# Out:
#     measure_x   name_of_company
# 0       24.23     Allied Signal
# 1       25.53     Bankers Trust
# 2       25.41     General Mills
# 3       24.14    ITT Industries
# 4       29.62  J.P.Morgan & Co.
# 5       28.25   Lehman Brothers
# 6       25.81          Marriott
# 7       24.39               MCI
# 8       40.26     Merrill Lynch
# 9       32.95         Microsoft
# 10      91.36    Morgan Stanley
# 11      25.99  Sun Microsystems
# 12      39.42         Travelers
# 13      26.71        US Airways
# 14      35.00    Warner-Lambert

# %%
plt.title('Name of Companies with respect to X', fontsize = 18, fontweight = 'bold', color='black')
ax = sns.barplot(y = measure_x, x = name_of_company, edgecolor='black')
plt.xticks(rotation = 90, fontsize = 12, fontweight = 'bold')
for i in ax.containers:
    ax.bar_label(i,)
plt.show()

# %%
sns.boxplot(measure_x)
plt.savefig('question1boxplot.png')
plt.show()

# %%
Q1.describe()
# Out:
#        measure_x
# count  15.000000
# mean   33.271333
# std    16.945401
# min    24.140000
# 25%    25.470000
# 50%    26.710000
# 75%    33.975000
# max    91.360000

# %%
print("Variance=",Q1.var())
# Out:
# Variance= measure_x    287.146612
# dtype: float64
# C:\Users\VAISHANVI\AppData\Local\Temp\ipykernel_22148\4185919116.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Variance=",Q1.var())
